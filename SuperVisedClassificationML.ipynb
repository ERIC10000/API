# %% [markdown]
# <a href="https://colab.research.google.com/github/ERIC10000/API/blob/main/SuperVisedClassificationML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Machine Learning:
# Artificial Intelligence: Process of bulding applications that posses
# human intelligence(learn(ML), understand env.(computer vision), communicate(speech reg/Natural Language Processing)...)

# ML: Deals with application learning from data.
# Deep Learning: Deals with applications learning from other source e,g images

# Categorized:
# 1. Supervised
# 2. Unsupervised Learning

# Supervised: It involves learning from a labeled data.Prediction
# Meaning into 2 aspects: Features/Predictors/Independent/X
#                       : Outcomes/Predicted/Dependent/Y
# In ML it is categorised into: Regression(Numbers), Classification(Text/Categorical Data)
# GOAL: Prediction

# Unsupervised: Deals with extracting underlying pattern in data
# Clustering and Association(Basket Analysis - Apriori Algorithm)

# kaggle.com - PIMA Indians Diabetes Datasets

# Classification: Predict Patient with Diabetes(PIMA Indians)
# Because the Outcome Variable Y is Categorical

# %%
# Step: Read Data
import pandas
model = GradientBoostingClassifier()
model.fit(X_train, Y_train)
data = pandas.read_csv("https://modcom.co.ke/data/datasets/pima.csv")
data
# Out:
#      Children  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           6      148             72             35        0  33.6
# 1           1       85             66             29        0  26.6
# 2           8      183             64              0        0  23.3
# 3           1       89             66             23       94  28.1
# 4           0      137             40             35      168  43.1
# ..        ...      ...            ...            ...      ...   ...
# 763        10      101             76             48      180  32.9
# 764         2      122             70             27        0  36.8
# 765         5      121             72             23      112  26.2
# 766         1      126             60              0        0  30.1
# 767         1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 0                       0.627   50      Diabetic
# 1                       0.351   31  Not Diabetic
# ...

# %%
# Preocessing and Data Analysis
# Statistical
data.describe()
# Out:
#          Children     Glucose  BloodPressure  SkinThickness     Insulin  \
# count  768.000000  768.000000     768.000000     768.000000  768.000000
# mean     3.845052  120.894531      69.105469      20.536458   79.799479
# std      3.369578   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      1.000000   99.000000      62.000000       0.000000    0.000000
# 50%      3.000000  117.000000      72.000000      23.000000   30.500000
# 75%      6.000000  140.250000      80.000000      32.000000  127.250000
# max     17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# ...

# %%
# Correlation
data.corr()
# Out:
# <ipython-input-68-a11f617e2317>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                           Children   Glucose  BloodPressure  SkinThickness  \
# Children                  1.000000  0.129459       0.141282      -0.081672
# Glucose                   0.129459  1.000000       0.152590       0.057328
# BloodPressure             0.141282  0.152590       1.000000       0.207371
# SkinThickness            -0.081672  0.057328       0.207371       1.000000
# Insulin                  -0.073535  0.331357       0.088933       0.436783
# BMI                       0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction -0.033523  0.137337       0.041265       0.183928
# Age                       0.544341  0.263514       0.239528      -0.113970
#
# ...

# %%
# Machine Learning Supervised Learning
# Step: 1(Supervised Learning)Supervised
# Divide the Data into Features and Outcome

array = data.values
array
# Out:
# array([[6, 148, 72, ..., 0.627, 50, 'Diabetic'],
#        [1, 85, 66, ..., 0.351, 31, 'Not Diabetic'],
#        [8, 183, 64, ..., 0.672, 32, 'Diabetic'],
#        ...,
#        [5, 121, 72, ..., 0.245, 30, 'Not Diabetic'],
#        [1, 126, 60, ..., 0.349, 47, 'Diabetic'],
#        [1, 93, 70, ..., 0.315, 23, 'Not Diabetic']], dtype=object)

# %%
# Features
X = array[:,   0:8 ]
X
# Out:
# array([[6, 148, 72, ..., 33.6, 0.627, 50],
#        [1, 85, 66, ..., 26.6, 0.351, 31],
#        [8, 183, 64, ..., 23.3, 0.672, 32],
#        ...,
#        [5, 121, 72, ..., 26.2, 0.245, 30],
#        [1, 126, 60, ..., 30.1, 0.349, 47],
#        [1, 93, 70, ..., 30.4, 0.315, 23]], dtype=object)

# %%
# listA = [1, 2, 3, 4, 5]
# print(listA[0:4])
# Out:
# [1, 2, 3, 4]

# %%
# Outcome
Y = array[:, 8]
Y
# Out:
# array(['Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
# ...

# %%
# Step 2: Split Data(X,Y) into Training(70%) and Testing(30%)
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.25, random_state=42)

# Why random state of 42 in ststistics?

# %%
# Step3: Import Scientific Algorithms for Training the Models
# Classifiers

# Imports Classification Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression   # Regression(LinearRegression)
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

# Feature Elimination
# Oversampling

# %%
# Step4: Cross - Validation -
# Process to Determine the Best Model for particular Datasets
models = []
models.append(('DTree', DecisionTreeClassifier()))
models.append(('Gaussian', GaussianNB()))
models.append(('KNC', KNeighborsClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('Gradient Boosting', GradientBoostingClassifier()))
models.append(('Linear Disc', LinearDiscriminantAnalysis()))
models.append(('Support Machines', SVC(gamma = 'auto')))
models.append(('LR', LogisticRegression(max_iter=1000)))

# Import Cross Validation and KFOLD
from sklearn.model_selection import cross_val_score, KFold
# Create a for loop so that each model is tested in turn
for name, model in models:
  # Here we do a 10 split K-FOLD
  from sklearn.model_selection import cross_val_score, KFold

  kfold = KFold(n_splits = 10, random_state=42, shuffle=True)
  # We get the results for each Fold
  cv_results = cross_val_score(model, X_train, Y_train, cv = kfold,
  scoring='accuracy')
  # Get the average of all Folds
  print('Model Name: ', name, ' Results: ', cv_results.mean())

# 200 -> 10 folds (Each 20 records)
# 1st -> 70, 2nd -> 73...10th 76
# Out:
# Model Name:  DTree  Results:  0.7319357092941998
# Model Name:  Gaussian  Results:  0.7507686932215234
# Model Name:  KNC  Results:  0.7208944793850453
# Model Name:  Random Forest  Results:  0.7653738644304682
# Model Name:  Gradient Boosting  Results:  0.7709643605870021
# Model Name:  Linear Disc  Results:  0.7729559748427673
# Model Name:  Support Machines  Results:  0.6498602375960866
# Model Name:  LR  Results:  0.7803633822501748

# %%
# step 5: Model Training - Machine Learns from the Training Data(X_train, Y_train)
# Training
model = GradientBoostingClassifier()
model.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Step6: Determine how accurate is the model for predicting?
# Model Evaluation
# Accuracy interms of Percentage

predictions = model.predict(X_test)
print(predictions)
# Out:
# ['Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
# ...

# %%
print(Y_test)
# Out:
# ['Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic'
# ...

# %%
# Accuracy Score: Metric for Evaluating model predictions againt Y_test
from sklearn.metrics import accuracy_score

print(f"The Accuracy {accuracy_score(predictions, Y_test) * 100}")


# Determine other model eva;uation techniques?
# 1. accuracy_score(predictions, Y_test)
# 2. confusion matrix
# 3. Precision and Recall
# 4. Classification Report
# Out:
# The Accuracy 74.89177489177489

# %%
#
# CV
# Feature Engineering
# Oversampling..
# Bias
data.groupby('Outcome').size()
# Out:
# Outcome
# Diabetic        268
# Not Diabetic    500
# dtype: int64

# %%
# prediction
features = [[2,20, 100, 85, 100, 41, 1.4, 47 ]]
diagnosis = model.predict(features)
print(f"You are 70% Likely to be {diagnosis}")
# Out:
# You are 70% Likely to be ['Not Diabetic']

# %%
data.head(2)
# Out:
#    Children  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0         6      148             72             35        0  33.6
# 1         1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age       Outcome
# 0                     0.627   50      Diabetic
# 1                     0.351   31  Not Diabetic

# %%
data.describe()
# Out:
#          Children     Glucose  BloodPressure  SkinThickness     Insulin  \
# count  768.000000  768.000000     768.000000     768.000000  768.000000
# mean     3.845052  120.894531      69.105469      20.536458   79.799479
# std      3.369578   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      1.000000   99.000000      62.000000       0.000000    0.000000
# 50%      3.000000  117.000000      72.000000      23.000000   30.500000
# 75%      6.000000  140.250000      80.000000      32.000000  127.250000
# max     17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# ...

# %%
data = pandas.read_csv("https://modcom.co.ke/datasets/bank.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Label Encoding.....

data['Gender'].replace({'Male': 0, 'Female': 1}, inplace=True)
data['Married'].replace({'No': 0, 'Yes': 1}, inplace=True)
data['Education'].replace({'Graduate': 0, 'Not Graduate': 1}, inplace=True)
meanL = data['LoanAmount'].mean()
data['LoanAmount'].fillna(meanL, inplace=True)

data.groupby('Property_Area').size()

# data.isnull().sum()
# Out:
# Property_Area
# Rural        179
# Semiurban    233
# Urban        202
# dtype: int64
