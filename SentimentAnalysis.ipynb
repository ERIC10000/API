# %% [markdown]
# <a href="https://colab.research.google.com/github/ERIC10000/API/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Text Analysis: Machines go through text(natural language) and give conclutions(insights)

# %%
import pandas
data = pandas.read_csv("https://modcom.co.ke/datasets/Tweets.csv")
data
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
# Data Analysis
data.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
# shape
data.shape
# Out:
# (14640, 15)

# %%
# Machine Learning
# Clasification: When the Y Outcome Variable is Text
# Regression : When the Y Outcome Variable is numbers(continous) e,g sales, temperature

# X - Fetures = text
# Y - Outcome = airline sentiment(positive, negative, neutral)

X = data['text']
Y = data['airline_sentiment']

# %%
# Spli Data Into Training(70%) and Testing(30%)
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# CountVectorizer -> Method to convert text to numerical data
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(lowercase=True, stop_words="english")
X_train_new = vectorizer.fit_transform(X_train)
print(X_train_new)
# Out:
#   (0, 6243)	1
#   (0, 4772)	1
#   (0, 1207)	1
#   (0, 10407)	1
#   (0, 5365)	1
#   (0, 6268)	1
#   (0, 10703)	1
#   (0, 4007)	1
#   (0, 2638)	1
#   (0, 6605)	1
#   (0, 5710)	1
#   (0, 4643)	1
#   (0, 430)	1
#   (0, 7047)	1
#   (0, 3294)	1
#   (1, 10703)	1
#   (1, 1739)	1
#   (1, 9588)	1
#   (1, 10685)	1
#   (1, 5496)	1
#   (1, 8870)	1
#   (1, 8190)	1
#   (1, 1942)	1
#   (1, 3794)	1
#   (2, 11346)	1
#   :	:
#   (10244, 5554)	1
#   (10245, 5633)	1
#   (10245, 9991)	1
#   (10245, 2901)	1
#   (10245, 5549)	1
#   (10245, 5719)	1
#   (10246, 11213)	1
#   (10246, 3552)	1
#   (10246, 9619)	1
#   (10246, 3336)	1
#   (10246, 9714)	1
#   (10246, 8394)	1
#   (10246, 4509)	1
#   (10246, 3901)	1
#   (10247, 6243)	2
#   (10247, 6685)	1
#   (10247, 6350)	1
#   (10247, 10344)	1
#   (10247, 9592)	1
#   (10247, 1963)	1
#   (10247, 7837)	1
#   (10247, 5414)	1
#   (10247, 11623)	1
#   (10247, 9586)	1
#   (10247, 10975)	1

# %%
# Bring Machine Models: Classification
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train_new, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# convert X_test into Numerical data using CountVectorizer
X_test_new = vectorizer.transform(X_test)
tested_sentiments = model.predict(X_test_new)
print(tested_sentiments)
print(Y_test)

# %%
# Testing the Sentiment
newdata = pandas.read_csv("https://modcom.co.ke/datasets/sample.csv")
newdata
# Out:
#                                                  Text
# 0   your airline is awesome but your lax loft need...
# 1   not worried, it's been a great ride in a new p...
# 2   awesome. I flew yall Sat morning. Any way we c...
# 3   Hi, Virgin! I'm on hold for 40-50 minutes -- a...
# 4                    Hi, Virgin, I like your services
# 5          Your services are bad, its not as expected
# 6   Its very unfortunate that I did not get what I...
# 7                          This is not good, improve!
# 8          I waited for 40 minutes but we left though
# 9                        this is very nice, I enjoyed
# 10      This is the worst plane experience in my life
# 11                I enjoyed my journey on this flight

# %%
newdata_vec = vectorizer.transform(newdata['Text'])
outcome = model.predict(newdata_vec)
outcome_data = pandas.DataFrame(outcome, columns = ['Sentiment'])
outcome_data
# Out:
#    Sentiment
# 0   positive
# 1   positive
# 2   positive
# 3    neutral
# 4    neutral
# 5   negative
# 6    neutral
# 7   negative
# 8    neutral
# 9   positive
# 10  negative
# 11  positive

# %%
# Merge the 2 dataframe: outcome, new data
results = pandas.merge(newdata, outcome_data, left_index=True, right_index=True)
results
# Out:
#                                                  Text Sentiment
# 0   your airline is awesome but your lax loft need...  positive
# 1   not worried, it's been a great ride in a new p...  positive
# 2   awesome. I flew yall Sat morning. Any way we c...  positive
# 3   Hi, Virgin! I'm on hold for 40-50 minutes -- a...   neutral
# 4                    Hi, Virgin, I like your services   neutral
# 5          Your services are bad, its not as expected  negative
# 6   Its very unfortunate that I did not get what I...   neutral
# 7                          This is not good, improve!  negative
# 8          I waited for 40 minutes but we left though   neutral
# 9                        this is very nice, I enjoyed  positive
# 10      This is the worst plane experience in my life  negative
# 11                I enjoyed my journey on this flight  positive

# %%
our_sentiments = {
    'Text': ['I really had fun during the flight, and very awesome', 'I will never use this arline again its so bad', 'Going to the US using BUsiness class, I want to test your airline']
}

# %%
data = pandas.DataFrame(our_sentiments)
data
# Out:
#                                                 Text
# 0  I really had fun during the flight, and very a...
# 1      I will never use this arline again its so bad
# 2  Going to the US using BUsiness class, I want t...

# %%
newdata_vec = vectorizer.transform(data['Text'])
outcome = model.predict(newdata_vec)
outcome_data = pandas.DataFrame(outcome, columns = ['Sentiment'])
outcome_data
# Out:
#   Sentiment
# 0  positive
# 1  negative
# 2  negative
